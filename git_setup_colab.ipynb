# %%
# !git config --global user.email "puntambekar.anand@gmail.com"
# !git config --global user.name "anandpuntambekar"
# !git config --global user.password " jksabfvnaeropvw"

# %%
token ='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'
username = 'anandpuntambekar'
repo ='streamlit_app_git'

# %%
! git clone https://{token}@github.com/{username}/{repo}
# Out:
# Cloning into 'streamlit_app_git'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), 598 bytes | 9.00 KiB/s, done.

# %%
# %cd
# Out:
# /content/drive/MyDrive/Colab Notebooks/Streamlit_Demo/streamlit_app_git

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	README (1).md
# 	car_pred
# 	cars24-car-price.csv
# 	git_setup_colab.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %% [markdown]
# # New Section

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/anandpuntambekar/streamlit_app.git
# Out:
# Cloning into 'streamlit_app'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), 598 bytes | 598.00 KiB/s, done.

# %%
# !git init
# !git add .
# !git commit -m "Initial commit, Files added"
# Out:
# Initialized empty Git repository in /content/.git/
# ...
# hint: You've added another git repository inside your current repository.
# hint: Clones of the outer repository will not contain the contents of
# hint: the embedded repository and will not know how to obtain it.
# hint: If you meant to add a submodule, use:
# hint:
# hint: 	git submodule add <url> streamlit_app
# hint:
# hint: If you added this path by mistake, you can remove it from the
# hint: index with:
# hint:
# hint: 	git rm --cached streamlit_app
# hint:
# hint: See "git help submodule" for more information.
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@e62d291e2c01.(none)')

# %%
# !git commit -m "Change file name to git_setup_colab"
# Out:
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@e62d291e2c01.(none)')

# %%
# !git checkout -b master
# Out:
# Switched to a new branch 'master'

# %%
# !git push -u origin master
# Out:
# error: src refspec master does not match any
# error: failed to push some refs to 'origin'

# %%
# !git config --global user.email "puntambekar.anand@gmail.com"
# !git config --global user.name "anandpuntambekar"

# %%
# !git add .
# !git commit -m "Initial commit Files added"
# Out:
# [master (root-commit) 3882ec3] Initial commit Files added
#  20 files changed, 50873 insertions(+)
#  create mode 100644 .config/.last_opt_in_prompt.yaml
#  create mode 100644 .config/.last_survey_prompt.yaml
#  create mode 100644 .config/.last_update_check.json
#  create mode 100644 .config/active_config
#  create mode 100644 .config/config_sentinel
#  create mode 100644 .config/configurations/config_default
#  create mode 100644 .config/gce
#  create mode 100644 .config/logs/2023.01.31/14.42.29.643459.log
#  create mode 100644 .config/logs/2023.01.31/14.42.55.609085.log
#  create mode 100644 .config/logs/2023.01.31/14.43.19.019539.log
#  create mode 100644 .config/logs/2023.01.31/14.43.27.028734.log
#  create mode 100644 .config/logs/2023.01.31/14.43.51.934868.log
#  create mode 100644 .config/logs/2023.01.31/14.43.52.650783.log
#  create mode 100755 sample_data/README.md
#  create mode 100755 sample_data/anscombe.json
#  create mode 100644 sample_data/california_housing_test.csv
# ...

# %%
# !git push -u streamlit_app master
# Out:
# Branch 'master' set up to track remote branch 'master' from 'streamlit_app'.
# Everything up-to-date

# %%
! git pull https://github.com/anandpuntambekar/streamlit_app.git main
# Out:
# ...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), 598 bytes | 598.00 KiB/s, done.
# From https://github.com/anandpuntambekar/streamlit_app
#  * branch            main       -> FETCH_HEAD
# fatal: refusing to merge unrelated histories

# %%
! git branch
# Out:
# * master

# %%
! git checkout main
# Out:
# error: pathspec 'main' did not match any file(s) known to git

# %%
# !git push -u streamlit_app master
# Out:
# Branch 'master' set up to track remote branch 'master' from 'streamlit_app'.
# Everything up-to-date
